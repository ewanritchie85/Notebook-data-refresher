# %%
import pandas as pd

df_customers = pd.read_csv('../CSVs/customers.csv')
df_products = pd.read_csv('../CSVs/products.csv')
df_orders = pd.read_csv('../CSVs/orders.csv')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# change input to display() accordingly to select which dataframe to display
display(df_products)
# Out:
#     product_id                              product_name           category  \
# 0      PRD_001                              Smart Webcam        Electronics
# 1      PRD_002                             Smart Speaker        Electronics
# 2      PRD_003                      Rechargeable Speaker        Electronics
# 3      PRD_004                           Wireless Router        Electronics
# 4      PRD_005                                4K Monitor        Electronics
# 5      PRD_006               Noise-Cancelling Headphones        Electronics
# 6      PRD_007                          Wireless Speaker        Electronics
# 7      PRD_008                         Gaming Headphones        Electronics
# 8      PRD_009                         Bluetooth Monitor        Electronics
# 9      PRD_010                       Gaming External SSD        Electronics
# 10     PRD_011                           Gaming Keyboard        Electronics
# ...
